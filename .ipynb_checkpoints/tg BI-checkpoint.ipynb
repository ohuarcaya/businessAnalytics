# %% [markdown]
# Financiera Compartamos
# -----------------------------------------

# %% [markdown]
# ## Limpieza de Datos

# %%
# warnings
import warnings
warnings.filterwarnings("ignore")
# import data
import numpy as np
import pandas as pd
df = pd.read_excel('data/dataOriginal.xlsx')
# cast to str
df.codigoCuenta=df.codigoCuenta.apply(str)
df.codigoCliente=df.codigoCliente.apply(str)
df.codigoFuente=df.codigoFuente.apply(str)
# cast to date
df.fechaApertura = pd.to_datetime(df.fechaApertura)
df.fechaVigencia = pd.to_datetime(df.fechaVigencia)
df.fechaUltimoPago = pd.to_datetime(df.fechaUltimoPago)
df.fechaVencimiento = pd.to_datetime(df.fechaVencimiento)
df.dSalPag = pd.to_datetime(df.dSalPag)
# drop useless columns
df.drop(['ctipcuo', 'fechaVigencia', 'fechaTermino', 'cestado', 
              'cComApr', 'diasDeAtraso', 'diasAtrasoMaximo'], axis=1, inplace=True)

# %% [markdown]
# ### Datos Cualitativos

# %%
df.describe(include=['object'])
# Out:
#         codigoCuenta codigoCliente codigoFuente tipoCredito sectorEconomico  \
# count          30575         30575        30575       30575           30575
# unique         30575         26412        25081           3               8
# top     322310001167      50128834     60000574           R              01
# freq               1             4           78       18526           14892
#
#        Fuente de financiamiento ctipcal       cctapre condicionCredito cmarjud
# count                     30575   30575         30575            30575   30575
# unique                       12       2           109                2       3
# top                          11       S                              Z       S
# freq                      18143   30471         30467            30433   27708

# %%
#un cliente puede tener varias cuentas, pero con diferentes tipos de asociaciones
dftest = df['codigoCuenta'].groupby([df['codigoCliente']]).count() #, df['company']
dftest
# Out:
# [('10000115', 29894    N
#   Name: tipoCredito, dtype: object), ('100001247', 13120    R
#   Name: tipoCredito, dtype: object), ('10000135', 7937    R
#   8528    R
#   Name: tipoCredito, dtype: object), ('100001379', 12559    R
#   Name: tipoCredito, dtype: object), ('100001528', 12557    R
#   12597    R
#   Name: tipoCredito, dtype: object), ('100001916', 12577    R
#   12604    R
#   Name: tipoCredito, dtype: object), ('100002468', 12991    R
#   12994    R
#   Name: tipoCredito, dtype: object), ('10000250', 23747    R
#   23793    R
#   Name: tipoCredito, dtype: object), ('100002716', 24766    U
#   Name: tipoCredito, dtype: object), ('10000273', 7933    R
#   7966    R
#   7978    R
#   Name: tipoCredito, dtype: object), ('100002930', 12765    R
#   Name: tipoCredito, dtype: object), ('100002989', 12722    R
#   12727    R
#   Name: tipoCredito, dtype: object), ('100003227', 12835    R
#   Name: tipoCredito, dtype: object), ('100003268', 12873    U
#   Name: tipoCredito, dtype: object), ('100003730', 12599    R
#   13081    R
#   Name: tipoCredito, dtype: object), ('100004043', 12926    R
#   Name: tipoCredito, dtype: object), ('10000441', 22716    R
#   23680    R
#   Name: tipoCredito, dtype: object), ('100004449', 12811    R
#   Name: tipoCredito, dtype: object), ('100004589', 12775    R
#   13105    R
#   Name: tipoCredito, dtype: object), ('10000473', 17657    U
#   Name: tipoCredito, dtype: object), ('100005453', 12995    R
#   13103    R
#   Name: tipoCredito, dtype: object), ('100005552', 12800    R
#   Name: tipoCredito, dtype: object), ('10000561', 23324    N
#   Name: tipoCredito, dtype: object), ('100005636', 12605    R
#   Name: tipoCredito, dtype: object), ('100005859', 12869    R
#   Name: tipoCredito, dtype: object), ('10000588', 27345    R
#   Name: tipoCredito, dtype: object), ('100005974', 12827    R
#   12856    R
#   Name: tipoCredito, dtype: object), ('100006477', 12896    R
#   12936    R
#   Name: tipoCredito, dtype: object), ('100006642', 24490    R
#   24536    R
#   Name: tipoCredito, dtype: object), ('100007129', 12823    R
#   Name: tipoCredito, dtype: object), ('100007236', 12898    R
#   Name: tipoCredito, dtype: object), ('100007277', 12852    R
#   12952    R
#   Name: tipoCredito, dtype: object), ('100007442', 12832    R
#   Name: tipoCredito, dtype: object), ('100007517', 24582    R
#   Name: tipoCredito, dtype: object), ('100007541', 12919    R
#   Name: tipoCredito, dtype: object), ('100007590', 12560    R
#   Name: tipoCredito, dtype: object), ('100007830', 13091    U
#   Name: tipoCredito, dtype: object), ('10000810', 27380    N
#   Name: tipoCredito, dtype: object), ('10000818', 1483    R
#   Name: tipoCredito, dtype: object), ('100008614', 12855    R
#   Name: tipoCredito, dtype: object), ('10000863', 1867    R
#   2096    R
#   Name: tipoCredito, dtype: object), ('100008903', 13089    R
#   Name: tipoCredito, dtype: object), ('100009737', 13097    R
#   Name: tipoCredito, dtype: object), ('100009885', 12865    R
#   Name: tipoCredito, dtype: object), ('100009968', 13072    R
#   13077    R
#   Name: tipoCredito, dtype: object), ('10001006', 15801    N
#   Name: tipoCredito, dtype: object), ('10001031', 319    R
#   Name: tipoCredito, dtype: object), ('10001093', 23001    R
#   23022    R
#   Name: tipoCredito, dtype: object), ('100011071', 12601    R
#   Name: tipoCredito, dtype: object), ('10001108', 5691    R
#   Name: tipoCredito, dtype: object), ('100011220', 12831    R
#   Name: tipoCredito, dtype: object), ('100011345', 12598    R
#   Name: tipoCredito, dtype: object), ('10001144', 1237    R
#   Name: tipoCredito, dtype: object), ('10001158', 8914    N
#   Name: tipoCredito, dtype: object), ('100011691', 12580    R
#   Name: tipoCredito, dtype: object), ('10001186', 12640    R
#   Name: tipoCredito, dtype: object), ('10001194', 1500    R
#   Name: tipoCredito, dtype: object), ('100012053', 13076    R
#   Name: tipoCredito, dtype: object), ('100012566', 12833    N
#   Name: tipoCredito, dtype: object), ('100012665', 12961    R
#   Name: tipoCredito, dtype: object), ('10001288', 1510    N
#   Name: tipoCredito, dtype: object), ('100013028', 12944    R
#   Name: tipoCredito, dtype: object), ('100013127', 13093    R
#   Name: tipoCredito, dtype: object), ('10001314', 22792    R
#   28289    R
#   Name: tipoCredito, dtype: object), ('10001325', 25430    R
#   Name: tipoCredito, dtype: object), ('10001334', 42       R
#   15840    R
#   Name: tipoCredito, dtype: object), ('100013465', 12924    U
#   Name: tipoCredito, dtype: object), ('100013549', 12562    R
#   Name: tipoCredito, dtype: object), ('100013713', 12723    R
#   Name: tipoCredito, dtype: object), ('100013853', 12802    R
#   Name: tipoCredito, dtype: object), ('100013952', 12574    R
#   Name: tipoCredito, dtype: object), ('100014091', 12561    R
#   Name: tipoCredito, dtype: object), ('100014158', 12850    R
#   12887    R
#   Name: tipoCredito, dtype: object), ('100014166', 13079    R
#   Name: tipoCredito, dtype: object), ('100014208', 12822    R
#   12844    R
#   Name: tipoCredito, dtype: object), ('100014299', 12834    R
#   Name: tipoCredito, dtype: object), ('100014604', 12772    R
#   Name: tipoCredito, dtype: object), ('100014653', 13094    R
#   Name: tipoCredito, dtype: object), ('100014794', 12810    R
#   Name: tipoCredito, dtype: object), ('100014927', 12804    R
#   12826    R
#   Name: tipoCredito, dtype: object), ('100014935', 12805    R
#   Name: tipoCredito, dtype: object), ('100014968', 12603    R
#   Name: tipoCredito, dtype: object), ('100015007', 12818    R
#   Name: tipoCredito, dtype: object), ('100015429', 13107    R
#   Name: tipoCredito, dtype: object), ('100015767', 12825    R
#   Name: tipoCredito, dtype: object), ('100015791', 12578    R
#   Name: tipoCredito, dtype: object), ('100015874', 12797    R
#   Name: tipoCredito, dtype: object), ('100015882', 12938    R
#   12998    R
#   Name: tipoCredito, dtype: object), ('100016195', 12854    R
#   12886    R
#   Name: tipoCredito, dtype: object), ('100016211', 13095    R
#   Name: tipoCredito, dtype: object), ('100016583', 12858    R
#   12891    R
#   Name: tipoCredito, dtype: object), ('10001684', 23679    R
#   23726    R
#   23778    R
#   Name: tipoCredito, dtype: object), ('100016849', 12813    R
#   Name: tipoCredito, dtype: object), ('100016856', 12784    R
#   Name: tipoCredito, dtype: object), ('100016872', 12798    R
#   Name: tipoCredito, dtype: object), ('10001695', 23777    U
#   23873    R
#   Name: tipoCredito, dtype: object), ('100016963', 12875    R
#   Name: tipoCredito, dtype: object), ('100016989', 12819    R
#   Name: tipoCredito, dtype: object), ('100017011', 12839    R
#   Name: tipoCredito, dtype: object), ('100017029', 13115    R
#   Name: tipoCredito, dtype: object), ('10001717', 576    U
#   Name: tipoCredito, dtype: object), ('100017193', 12824    R
#   Name: tipoCredito, dtype: object), ('100017235', 12763    R
#   Name: tipoCredito, dtype: object), ('100017805', 12799    R
#   Name: tipoCredito, dtype: object), ('100017862', 13086    R
#   Name: tipoCredito, dtype: object), ('100018365', 12733    R
#   Name: tipoCredito, dtype: object), ('100018464', 12971    R
#   12987    R
#   Name: tipoCredito, dtype: object), ('100018506', 13082    R
#   Name: tipoCredito, dtype: object), ('100018555', 12796    R
#   Name: tipoCredito, dtype: object), ('100018639', 12872    U
#   12885    R
#   Name: tipoCredito, dtype: object), ('100018696', 12600    R
#   Name: tipoCredito, dtype: object), ('100018852', 12812    R
#   12820    R
#   Name: tipoCredito, dtype: object), ('100019322', 12726    R
#   Name: tipoCredito, dtype: object), ('100019355', 12871    R
#   Name: tipoCredito, dtype: object), ('100019546', 12721    R
#   Name: tipoCredito, dtype: object), ('100019819', 13123    R
#   Name: tipoCredito, dtype: object), ('100020114', 12795    R
#   Name: tipoCredito, dtype: object), ('100020346', 12556    N
#   Name: tipoCredito, dtype: object), ('100020510', 12575    N
#   Name: tipoCredito, dtype: object), ('100020593', 12843    R
#   Name: tipoCredito, dtype: object), ('100020668', 12814    R
#   12838    R
#   Name: tipoCredito, dtype: object), ('100020809', 13106    R
#   13110    R
#   Name: tipoCredito, dtype: object), ('100020882', 12965    R
#   Name: tipoCredito, dtype: object), ('100021104', 12576    N
#   Name: tipoCredito, dtype: object), ('100021229', 12596    R
#   Name: tipoCredito, dtype: object), ('100021385', 12840    R
#   Name: tipoCredito, dtype: object), ('100021765', 12905    R
#   Name: tipoCredito, dtype: object), ('100021807', 12579    N
#   Name: tipoCredito, dtype: object), ('10002216', 4760    R
#   Name: tipoCredito, dtype: object), ('100022201', 12910    R
#   12925    R
#   Name: tipoCredito, dtype: object), ('100022367', 12582    N
#   Name: tipoCredito, dtype: object), ('100022565', 12807    R
#   Name: tipoCredito, dtype: object), ('100022649', 12893    R
#   12929    R
#   Name: tipoCredito, dtype: object), ('100022664', 12719    N
#   Name: tipoCredito, dtype: object), ('100022714', 13084    U
#   Name: tipoCredito, dtype: object), ('100022789', 12913    R
#   Name: tipoCredito, dtype: object), ('100022854', 12911    R
#   Name: tipoCredito, dtype: object), ('100022912', 12584    N
#   Name: tipoCredito, dtype: object), ('100022938', 12829    R
#   Name: tipoCredito, dtype: object), ('100022987', 12894    R
#   Name: tipoCredito, dtype: object), ('100023126', 12867    U
#   Name: tipoCredito, dtype: object), ('100023522', 12930    R
#   Name: tipoCredito, dtype: object), ('100024009', 12602    N
#   Name: tipoCredito, dtype: object), ('100024165', 12783    N
#   Name: tipoCredito, dtype: object), ('100024421', 13098    R
#   Name: tipoCredito, dtype: object), ('100024553', 12606    N
#   Name: tipoCredito, dtype: object), ('10002458', 4429    N
#   Name: tipoCredito, dtype: object), ('100024652', 12725    R
#   Name: tipoCredito, dtype: object), ('100025154', 12816    R
#   12837    R
#   Name: tipoCredito, dtype: object), ('100025253', 12744    R
#   Name: tipoCredito, dtype: object), ('100025808', 12718    N
#   12808    R
#   Name: tipoCredito, dtype: object), ('100025857', 12841    R
#   Name: tipoCredito, dtype: object), ('100026343', 12904    U
#   Name: tipoCredito, dtype: object), ('100026723', 12724    N
#   Name: tipoCredito, dtype: object), ('100026749', 12735    R
#   Name: tipoCredito, dtype: object), ('100026830', 12731    R
#   Name: tipoCredito, dtype: object), ('100026848', 12801    N
#   Name: tipoCredito, dtype: object), ('100027309', 12790    N
#   Name: tipoCredito, dtype: object), ('100027325', 12877    R
#   Name: tipoCredito, dtype: object), ('100027408', 12803    N
#   Name: tipoCredito, dtype: object), ('100027416', 12730    R
#   Name: tipoCredito, dtype: object), ('100027481', 12729    R
#   Name: tipoCredito, dtype: object), ('100027705', 12806    N
#   Name: tipoCredito, dtype: object), ('100027960', 12849    R
#   12864    R
#   Name: tipoCredito, dtype: object), ('100028265', 12728    N
#   Name: tipoCredito, dtype: object), ('100028331', 12892    R
#   Name: tipoCredito, dtype: object), ('100028406', 12745    R
#   12757    R
#   Name: tipoCredito, dtype: object), ('100028919', 12815    N
#   Name: tipoCredito, dtype: object), ('10002894', 8611    U
#   Name: tipoCredito, dtype: object), ('100028943', 13114    R
#   Name: tipoCredito, dtype: object), ('100029339', 12900    R
#   Name: tipoCredito, dtype: object), ('100029347', 13122    R
#   Name: tipoCredito, dtype: object), ('100029388', 12766    R
#   12777    R
#   Name: tipoCredito, dtype: object), ('100029529', 12746    R
#   Name: tipoCredito, dtype: object), ('100029883', 12817    N
#   Name: tipoCredito, dtype: object), ('100029974', 12906    R
#   Name: tipoCredito, dtype: object), ('100030105', 27310    R
#   Name: tipoCredito, dtype: object), ('100030212', 12988    R
#   Name: tipoCredito, dtype: object), ('100030519', 12975    R
#   Name: tipoCredito, dtype: object), ('100030527', 12821    N
#   Name: tipoCredito, dtype: object), ('100030709', 13092    R
#   13101    R
#   Name: tipoCredito, dtype: object), ('100030824', 12882    R
#   Name: tipoCredito, dtype: object), ('100030857', 12918    R
#   Name: tipoCredito, dtype: object), ('100030964', 12889    R
#   Name: tipoCredito, dtype: object), ('100031384', 12860    R
#   Name: tipoCredito, dtype: object), ('100031574', 12740    R
#   Name: tipoCredito, dtype: object), ('100031814', 12890    R
#   Name: tipoCredito, dtype: object), ('100032002', 12732    N
#   Name: tipoCredito, dtype: object), ('100032028', 12888    R
#   Name: tipoCredito, dtype: object), ('100032275', 12953    R
#   Name: tipoCredito, dtype: object), ('100032325', 12895    R
#   Name: tipoCredito, dtype: object), ('100032689', 12940    R
#   Name: tipoCredito, dtype: object), ('100032754', 12737    R
#   Name: tipoCredito, dtype: object), ('100032903', 12963    R
#   Name: tipoCredito, dtype: object), ('100032960', 12830    N
#   Name: tipoCredito, dtype: object), ('100033034', 12828    N
#   Name: tipoCredito, dtype: object), ('100033141', 12842    R
#   Name: tipoCredito, dtype: object), ('100033356', 12734    N
#   Name: tipoCredito, dtype: object), ('100034495', 12836    N
#   Name: tipoCredito, dtype: object), ('100034602', 13104    R
#   Name: tipoCredito, dtype: object), ('100034776', 12736    N
#   Name: tipoCredito, dtype: object), ('100035039', 13100    R
#   Name: tipoCredito, dtype: object), ('100035104', 12880    R
#   Name: tipoCredito, dtype: object), ('100035203', 12937    R
#   Name: tipoCredito, dtype: object), ('100035211', 12755    R
#   Name: tipoCredito, dtype: object), ('100036011', 12883    R
#   Name: tipoCredito, dtype: object), ('100036326', 12967    R
#   Name: tipoCredito, dtype: object), ('100036383', 12789    R
#   Name: tipoCredito, dtype: object), ('100036532', 13080    N
#   Name: tipoCredito, dtype: object), ('100036607', 12749    R
#   Name: tipoCredito, dtype: object), ('100036763', 12738    N
#   Name: tipoCredito, dtype: object), ('100036912', 12846    N
#   Name: tipoCredito, dtype: object), ('100037241', 12848    N
#   Name: tipoCredito, dtype: object), ('100037266', 12847    N
#   Name: tipoCredito, dtype: object), ('100037381', 12915    R
#   Name: tipoCredito, dtype: object), ('100037522', 12903    R
#   Name: tipoCredito, dtype: object), ('100037605', 12942    R
#   12964    R
#   Name: tipoCredito, dtype: object), ('100037621', 12907    R
#   Name: tipoCredito, dtype: object), ('100037647', 12851    N
#   Name: tipoCredito, dtype: object), ('100037654', 12966    R
#   Name: tipoCredito, dtype: object), ('100037704', 12739    N
#   Name: tipoCredito, dtype: object), ('100037803', 12922    R
#   Name: tipoCredito, dtype: object), ('100037878', 12753    R
#   Name: tipoCredito, dtype: object), ('100037910', 12741    N
#   Name: tipoCredito, dtype: object), ('100037936', 12853    N
#   Name: tipoCredito, dtype: object), ('100038066', 12782    R
#   Name: tipoCredito, dtype: object), ('100038207', 12912    R
#   12962    R
#   Name: tipoCredito, dtype: object), ('100038397', 12859    N
#   Name: tipoCredito, dtype: object), ('100038462', 12754    R
#   Name: tipoCredito, dtype: object), ('100038520', 12742    N
#   12751    R
#   Name: tipoCredito, dtype: object), ('100038561', 12977    R
#   Name: tipoCredito, dtype: object), ('100038611', 12752    R
#   Name: tipoCredito, dtype: object), ('100038702', 12861    N
#   Name: tipoCredito, dtype: object), ('100038801', 12862    N
#   Name: tipoCredito, dtype: object), ('100038843', 12750    R
#   Name: tipoCredito, dtype: object), ('100038892', 12743    N
#   Name: tipoCredito, dtype: object), ('100039189', 13102    R
#   Name: tipoCredito, dtype: object), ('100039270', 12756    R
#   Name: tipoCredito, dtype: object), ('100039353', 12866    N
#   Name: tipoCredito, dtype: object), ('100039361', 12996    N
#   Name: tipoCredito, dtype: object), ('100039403', 12793    N
#   Name: tipoCredito, dtype: object), ('100039528', 12902    R
#   Name: tipoCredito, dtype: object), ('100039981', 12868    N
#   Name: tipoCredito, dtype: object), ('100039999', 13087    N
#   Name: tipoCredito, dtype: object), ('100040120', 12870    N
#   Name: tipoCredito, dtype: object), ('100040294', 12747    N
#   Name: tipoCredito, dtype: object), ('100040385', 12748    N
#   Name: tipoCredito, dtype: object), ('100040401', 13099    R
#   Name: tipoCredito, dtype: object), ('100040575', 12951    R
#   Name: tipoCredito, dtype: object), ('100040682', 12769    R
#   Name: tipoCredito, dtype: object), ('100040690', 12874    N
#   Name: tipoCredito, dtype: object), ('100040815', 12908    R
#   Name: tipoCredito, dtype: object), ('100041110', 12767    R
#   12776    R
#   Name: tipoCredito, dtype: object), ('100041268', 12973    R
#   Name: tipoCredito, dtype: object), ('100041524', 12931    R
#   Name: tipoCredito, dtype: object), ('100041573', 12879    N
#   Name: tipoCredito, dtype: object), ('100042050', 12921    R
#   Name: tipoCredito, dtype: object), ('100042217', 12881    N
#   Name: tipoCredito, dtype: object), ('100042399', 12972    R
#   Name: tipoCredito, dtype: object), ('100042597', 12778    R
#   Name: tipoCredito, dtype: object), ('100042746', 12884    N
#   Name: tipoCredito, dtype: object), ('100042829', 12932    R
#   Name: tipoCredito, dtype: object), ('100042860', 12761    R
#   Name: tipoCredito, dtype: object), ('100043199', 12950    U
#   Name: tipoCredito, dtype: object), ('100043207', 12957    R
#   Name: tipoCredito, dtype: object), ('100043462', 12758    N
#   Name: tipoCredito, dtype: object), ('100043520', 12759    N
#   Name: tipoCredito, dtype: object), ('100043835', 12760    N
#   Name: tipoCredito, dtype: object), ('100043884', 12897    N
#   Name: tipoCredito, dtype: object), ('100043892', 12916    R
#   Name: tipoCredito, dtype: object), ('100043900', 12955    R
#   Name: tipoCredito, dtype: object), ('100044130', 12981    R
#   Name: tipoCredito, dtype: object), ('100044163', 12899    N
#   Name: tipoCredito, dtype: object), ('100044296', 12901    N
#   Name: tipoCredito, dtype: object), ('100044411', 12989    R
#   Name: tipoCredito, dtype: object), ('100045087', 12787    R
#   Name: tipoCredito, dtype: object), ('100045160', 12792    N
#   Name: tipoCredito, dtype: object), ('100045475', 12986    R
#   Name: tipoCredito, dtype: object), ('100045558', 12909    N
#   Name: tipoCredito, dtype: object), ('100045590', 12762    N
#   Name: tipoCredito, dtype: object), ('100045608', 12949    R
#   Name: tipoCredito, dtype: object), ('100045830', 12914    N
#   Name: tipoCredito, dtype: object), ('100046242', 12764    N
#   Name: tipoCredito, dtype: object), ('100046507', 12920    N
#   Name: tipoCredito, dtype: object), ('100046598', 12768    N
#   12774    R
#   Name: tipoCredito, dtype: object), ('100046739', 12923    N
#   Name: tipoCredito, dtype: object), ('100046887', 12933    N
#   Name: tipoCredito, dtype: object), ('100047695', 12934    N
#   Name: tipoCredito, dtype: object), ('100047802', 12993    R
#   Name: tipoCredito, dtype: object), ('100047828', 12935    N
#   Name: tipoCredito, dtype: object), ('100047844', 12947    R
#   Name: tipoCredito, dtype: object), ('100048206', 12770    N
#   Name: tipoCredito, dtype: object), ('100048263', 12939    N
#   Name: tipoCredito, dtype: object), ('100048271', 12984    R
#   Name: tipoCredito, dtype: object), ('100048412', 12979    R
#   Name: tipoCredito, dtype: object), ('100048453', 12941    N
#   Name: tipoCredito, dtype: object), ('100048792', 12771    N
#   Name: tipoCredito, dtype: object), ('100049014', 12943    N
#   Name: tipoCredito, dtype: object), ('100049055', 12945    N
#   Name: tipoCredito, dtype: object), ('100049295', 12946    N
#   Name: tipoCredito, dtype: object), ('100049329', 12948    N
#   Name: tipoCredito, dtype: object), ('100049469', 27307    R
#   Name: tipoCredito, dtype: object), ('100049527', 12773    N
#   Name: tipoCredito, dtype: object), ('100049618', 12954    N
#   Name: tipoCredito, dtype: object), ('100049659', 12956    N
#   Name: tipoCredito, dtype: object), ('100049758', 12958    N
#   Name: tipoCredito, dtype: object), ('100049857', 13109    N
#   Name: tipoCredito, dtype: object), ('100049873', 12959    N
#   Name: tipoCredito, dtype: object), ('100050392', 12779    N
#   Name: tipoCredito, dtype: object), ('100050566', 12781    N
#   Name: tipoCredito, dtype: object), ('100050616', 12968    N
#   Name: tipoCredito, dtype: object), ('100050772', 12780    N
#   Name: tipoCredito, dtype: object), ('100050897', 13113    N
#   Name: tipoCredito, dtype: object), ('100051044', 12970    N
#   Name: tipoCredito, dtype: object), ('100051051', 12976    N
#   Name: tipoCredito, dtype: object), ('100051259', 13116    N
#   Name: tipoCredito, dtype: object), ('100051317', 12785    N
#   Name: tipoCredito, dtype: object), ('100051358', 12786    N
#   Name: tipoCredito, dtype: object), ('100051432', 12978    N
#   Name: tipoCredito, dtype: object), ('100051697', 13117    N
#   Name: tipoCredito, dtype: object), ('100051705', 12980    N
#   Name: tipoCredito, dtype: object), ('100051721', 12982    N
#   Name: tipoCredito, dtype: object), ('100051895', 12983    N
#   Name: tipoCredito, dtype: object), ('100052174', 12990    N
#   Name: tipoCredito, dtype: object), ('100052737', 12791    N
#   Name: tipoCredito, dtype: object), ('100053412', 12997    N
#   Name: tipoCredito, dtype: object), ('100053768', 27309    N
#   Name: tipoCredito, dtype: object), ('100054113', 27311    N
#   Name: tipoCredito, dtype: object), ('100054147', 12794    N
#   Name: tipoCredito, dtype: object), ('10200167', 13118    R
#   Name: tipoCredito, dtype: object), ('10200318', 12928    R
#   12992    R
#   Name: tipoCredito, dtype: object), ('10200381', 12863    R
#   Name: tipoCredito, dtype: object), ('10200414', 13111    R
#   13121    R
#   Name: tipoCredito, dtype: object), ('10300297', 4155    R
#   Name: tipoCredito, dtype: object), ('10400924', 21664    N
#   21737    R
#   Name: tipoCredito, dtype: object), ('110000262', 13671    R
#   Name: tipoCredito, dtype: object), ('110000734', 13489    R
#   Name: tipoCredito, dtype: object), ('110000817', 14676    R
#   14762    R
#   Name: tipoCredito, dtype: object), ('110000957', 14566    R
#   Name: tipoCredito, dtype: object), ('110000973', 13129    R
#   Name: tipoCredito, dtype: object), ('110001062', 11330    R
#   Name: tipoCredito, dtype: object), ('110001187', 13194    R
#   Name: tipoCredito, dtype: object), ('110001328', 13531    R
#   Name: tipoCredito, dtype: object), ('110001807', 11313    R
#   Name: tipoCredito, dtype: object), ('110001849', 13205    R
#   Name: tipoCredito, dtype: object), ('110002169', 14890    R
#   Name: tipoCredito, dtype: object), ('110002318', 13552    R
#   13629    R
#   Name: tipoCredito, dtype: object), ('110002342', 13540    R
#   Name: tipoCredito, dtype: object), ('110002581', 13222    R
#   Name: tipoCredito, dtype: object), ('110002722', 13248    R
#   Name: tipoCredito, dtype: object), ('110002763', 14650    R
#   Name: tipoCredito, dtype: object), ('110003357', 13636    R
#   Name: tipoCredito, dtype: object), ('110003670', 13133    R
#   Name: tipoCredito, dtype: object), ('110003712', 13140    R
#   13482    R
#   Name: tipoCredito, dtype: object), ('110003720', 13203    R
#   13213    R
#   Name: tipoCredito, dtype: object), ('110003738', 13156    R
#   Name: tipoCredito, dtype: object), ('110003746', 11345    R
#   Name: tipoCredito, dtype: object), ('110003779', 11318    R
#   14319    R
#   Name: tipoCredito, dtype: object), ('110003878', 13458    R
#   13572    R
#   Name: tipoCredito, dtype: object), ('110003944', 11305    R
#   14159    R
#   Name: tipoCredito, dtype: object), ('110003977', 13220    R
#   Name: tipoCredito, dtype: object), ('110003985', 13157    R
#   Name: tipoCredito, dtype: object), ('110004181', 14396    R
#   Name: tipoCredito, dtype: object), ('110004538', 14555    R
#   14600    R
#   Name: tipoCredito, dtype: object), ('110004660', 13138    R
#   Name: tipoCredito, dtype: object), ('110004918', 13149    R
#   Name: tipoCredito, dtype: object), ('110004942', 13128    R
#   13169    R
#   Name: tipoCredito, dtype: object), ('110005089', 14554    R
#   Name: tipoCredito, dtype: object), ('110005113', 13191    R
#   Name: tipoCredito, dtype: object), ('110005170', 13130    R
#   13188    R
#   Name: tipoCredito, dtype: object), ('110005212', 11115    R
#   13210    R
#   13224    R
#   Name: tipoCredito, dtype: object), ('110005253', 11307    R
#   Name: tipoCredito, dtype: object), ('110005337', 14737    R
#   Name: tipoCredito, dtype: object), ('110005451', 13134    R
#   Name: tipoCredito, dtype: object), ('110005543', 13478    R
#   Name: tipoCredito, dtype: object), ('110005584', 14433    R
#   Name: tipoCredito, dtype: object), ('110005592', 14494    R
#   Name: tipoCredito, dtype: object), ('110005790', 13150    U
#   Name: tipoCredito, dtype: object), ('110005832', 13192    R
#   Name: tipoCredito, dtype: object), ('110006053', 13215    R
#   14175    R
#   Name: tipoCredito, dtype: object), ('110006160', 13509    R
#   Name: tipoCredito, dtype: object), ('110006574', 14576    R
#   30002    R
#   Name: tipoCredito, dtype: object), ('110006764', 13132    R
#   Name: tipoCredito, dtype: object), ('110006921', 13160    R
#   13212    R
#   Name: tipoCredito, dtype: object), ('110007234', 13170    R
#   13209    R
#   Name: tipoCredito, dtype: object), ('110007358', 13493    R
#   13576    R
#   Name: tipoCredito, dtype: object), ('110007424', 13131    R
#   Name: tipoCredito, dtype: object), ('110007770', 13518    R
#   13633    R
#   Name: tipoCredito, dtype: object), ('110007903', 14156    R
#   Name: tipoCredito, dtype: object), ('110008141', 14231    R
#   14301    R
#   Name: tipoCredito, dtype: object), ('110008323', 11321    U
#   11324    R
#   Name: tipoCredito, dtype: object), ('110008539', 13667    R
#   Name: tipoCredito, dtype: object), ('110008554', 13603    R
#   Name: tipoCredito, dtype: object), ('110008638', 13178    R
#   13214    R
#   Name: tipoCredito, dtype: object), ('110008653', 11308    R
#   Name: tipoCredito, dtype: object), ('110008935', 14362    R
#   Name: tipoCredito, dtype: object), ('110009099', 13556    R
#   Name: tipoCredito, dtype: object), ('110009107', 14547    R
#   14603    R
#   Name: tipoCredito, dtype: object), ('110009305', 14476    U
#   Name: tipoCredito, dtype: object), ('110009529', 14755    N
#   Name: tipoCredito, dtype: object), ('110009677', 13466    R
#   Name: tipoCredito, dtype: object), ('110009941', 13136    R
#   Name: tipoCredito, dtype: object), ('110010113', 11346    U
#   Name: tipoCredito, dtype: object), ('110010303', 11326    R
#   Name: tipoCredito, dtype: object), ('110010360', 13525    R
#   Name: tipoCredito, dtype: object), ('110010410', 14328    R
#   Name: tipoCredito, dtype: object), ('110010477', 11970    R
#   Name: tipoCredito, dtype: object), ('110010592', 13541    R
#   13641    R
#   Name: tipoCredito, dtype: object), ('110010667', 14822    R
#   Name: tipoCredito, dtype: object), ('110010808', 13244    R
#   Name: tipoCredito, dtype: object), ('110010956', 13142    R
#   Name: tipoCredito, dtype: object), ('110011418', 14699    R
#   Name: tipoCredito, dtype: object), ('110011574', 11302    R
#   Name: tipoCredito, dtype: object), ('110011871', 13474    R
#   14173    R
#   Name: tipoCredito, dtype: object), ('110011913', 13196    R
#   Name: tipoCredito, dtype: object), ('110012028', 13137    R
#   Name: tipoCredito, dtype: object), ('110012606', 13232    R
#   13627    R
#   Name: tipoCredito, dtype: object), ('110012614', 14510    R
#   Name: tipoCredito, dtype: object), ('110012705', 13125    R
#   Name: tipoCredito, dtype: object), ('110012762', 13141    R
#   13190    R
#   Name: tipoCredito, dtype: object), ('110012903', 13526    R
#   14158    R
#   Name: tipoCredito, dtype: object), ('110013067', 11299    U
#   Name: tipoCredito, dtype: object), ('110013554', 11334    R
#   11338    R
#   13669    R
#   Name: tipoCredito, dtype: object), ('110013588', 13179    R
#   13207    R
#   Name: tipoCredito, dtype: object), ('110013638', 13247    R
#   Name: tipoCredito, dtype: object), ('110013901', 13145    R
#   Name: tipoCredito, dtype: object), ('110013950', 13498    R
#   Name: tipoCredito, dtype: object), ('110014289', 14672    R
#   Name: tipoCredito, dtype: object), ('110014370', 13237    R
#   Name: tipoCredito, dtype: object), ('110014461', 13533    R
#   13616    R
#   Name: tipoCredito, dtype: object), ('110014529', 13551    R
#   Name: tipoCredito, dtype: object), ('110014610', 14531    R
#   Name: tipoCredito, dtype: object), ('110014677', 13599    R
#   14373    R
#   14445    R
#   Name: tipoCredito, dtype: object), ('110014693', 13201    R
#   13211    R
#   Name: tipoCredito, dtype: object), ('110015153', 13127    R
#   Name: tipoCredito, dtype: object), ('110015187', 13166    R
#   Name: tipoCredito, dtype: object), ('110015310', 13177    R
#   Name: tipoCredito, dtype: object), ('110015641', 13246    R
#   Name: tipoCredito, dtype: object), ('110015674', 11116    N
#   Name: tipoCredito, dtype: object), ('110015708', 13614    R
#   Name: tipoCredito, dtype: object), ('110015815', 13240    R
#   Name: tipoCredito, dtype: object), ('110015831', 13154    R
#   Name: tipoCredito, dtype: object), ('110015906', 13208    R
#   13472    R
#   Name: tipoCredito, dtype: object), ('110016011', 14730    R
#   14821    R
#   Name: tipoCredito, dtype: object), ('110016136', 13183    R
#   Name: tipoCredito, dtype: object), ('110016243', 13148    R
#   Name: tipoCredito, dtype: object), ('110016375', 14238    R
#   Name: tipoCredito, dtype: object), ('110016433', 11111    R
#   Name: tipoCredito, dtype: object), ('110016805', 13146    R
#   Name: tipoCredito, dtype: object), ('110016870', 13610    R
#   Name: tipoCredito, dtype: object), ('110016888', 13510    R
#   13517    R
#   Name: tipoCredito, dtype: object), ('110017407', 13465    R
#   Name: tipoCredito, dtype: object), ('110017456', 14541    R
#   Name: tipoCredito, dtype: object), ('110017639', 13151    R
#   Name: tipoCredito, dtype: object), ('110017647', 13152    N
#   Name: tipoCredito, dtype: object), ('110017712', 13174    R
#   Name: tipoCredito, dtype: object), ('110017779', 13635    N
#   Name: tipoCredito, dtype: object), ('110018041', 13292    U
#   Name: tipoCredito, dtype: object), ('110018116', 13235    R
#   Name: tipoCredito, dtype: object), ('110018132', 14237    R
#   Name: tipoCredito, dtype: object), ('110018827', 13456    R
#   Name: tipoCredito, dtype: object), ('110018884', 13172    R
#   Name: tipoCredito, dtype: object), ('110018892', 13182    R
#   Name: tipoCredito, dtype: object), ('110018926', 13539    R
#   14300    R
#   Name: tipoCredito, dtype: object), ('110018942', 14743    U
#   Name: tipoCredito, dtype: object), ('110018975', 13673    U
#   Name: tipoCredito, dtype: object), ('110019288', 14695    R
#   14796    R
#   Name: tipoCredito, dtype: object), ('110019346', 13126    N
#   Name: tipoCredito, dtype: object), ('110019494', 13665    R
#   Name: tipoCredito, dtype: object), ('110019502', 13143    N
#   Name: tipoCredito, dtype: object), ('110019585', 14272    R
#   14366    R
#   Name: tipoCredito, dtype: object), ('110019734', 13454    R
#   Name: tipoCredito, dtype: object), ('110019759', 13147    N
#   Name: tipoCredito, dtype: object), ('110019775', 13204    R
#   Name: tipoCredito, dtype: object), ('110019973', 14348    R
#   14496    R
#   Name: tipoCredito, dtype: object), ('110020039', 14448    R
#   Name: tipoCredito, dtype: object), ('110020153', 14408    R
#   14816    R
#   Name: tipoCredito, dtype: object), ('110020161', 13197    R
#   Name: tipoCredito, dtype: object), ('110020187', 13153    N
#   Name: tipoCredito, dtype: object), ('110020252', 14155    R
#   Name: tipoCredito, dtype: object), ('110020468', 13643    R
#   Name: tipoCredito, dtype: object), ('110021003', 13158    N
#   Name: tipoCredito, dtype: object), ('110021029', 13159    N
#   Name: tipoCredito, dtype: object), ('110021045', 13161    N
#   Name: tipoCredito, dtype: object), ('110021102', 13162    N
#   Name: tipoCredito, dtype: object), ('110021110', 14668    R
#   Name: tipoCredito, dtype: object), ('110021151', 13230    R
#   13488    R
#   Name: tipoCredito, dtype: object), ('110021318', 13164    N
#   Name: tipoCredito, dtype: object), ('110021326', 28219    R
#   Name: tipoCredito, dtype: object), ('110021409', 13630    R
#   Name: tipoCredito, dtype: object), ('110021441', 14372    R
#   14390    R
#   Name: tipoCredito, dtype: object), ('110021615', 13241    N
#   Name: tipoCredito, dtype: object), ('110021649', 14202    R
#   Name: tipoCredito, dtype: object), ('110021698', 13167    N
#   Name: tipoCredito, dtype: object), ('110021706', 11351    R
#   Name: tipoCredito, dtype: object), ('110021748', 13171    N
#   Name: tipoCredito, dtype: object), ('110021755', 14605    R
#   Name: tipoCredito, dtype: object), ('110021938', 10981    R
#   11301    R
#   11310    R
#   Name: tipoCredito, dtype: object), ('110021946', 13461    R
#   Name: tipoCredito, dtype: object), ('110022167', 13546    R
#   Name: tipoCredito, dtype: object), ('110022217', 13173    N
#   Name: tipoCredito, dtype: object), ('110022308', 13453    R
#   Name: tipoCredito, dtype: object), ('110022316', 13175    N
#   Name: tipoCredito, dtype: object), ('110022332', 13176    N
#   Name: tipoCredito, dtype: object), ('110022571', 14853    R
#   Name: tipoCredito, dtype: object), ('110022597', 13570    R
#   Name: tipoCredito, dtype: object), ('110022720', 13242    N
#   Name: tipoCredito, dtype: object), ('110023025', 13460    R
#   Name: tipoCredito, dtype: object), ('110023033', 13562    N
#   Name: tipoCredito, dtype: object), ('110023140', 29994    R
#   30063    R
#   Name: tipoCredito, dtype: object), ('110023165', 14232    R
#   14309    R
#   Name: tipoCredito, dtype: object), ('110023215', 13180    N
#   Name: tipoCredito, dtype: object), ('110023397', 14403    R
#   Name: tipoCredito, dtype: object), ('110023538', 14339    U
#   Name: tipoCredito, dtype: object), ('110023710', 13181    N
#   Name: tipoCredito, dtype: object), ('110023728', 14369    R
#   Name: tipoCredito, dtype: object), ('110023785', 13243    N
#   Name: tipoCredito, dtype: object), ('110023835', 13548    R
#   14203    R
#   Name: tipoCredito, dtype: object), ('110023868', 14406    R
#   14472    R
#   Name: tipoCredito, dtype: object), ('110023892', 13468    R
#   Name: tipoCredito, dtype: object), ('110024015', 30073    R
#   Name: tipoCredito, dtype: object), ('110024114', 13505    R
#   Name: tipoCredito, dtype: object), ('110024163', 13544    R
#   Name: tipoCredito, dtype: object), ('110024213', 14514    U
#   Name: tipoCredito, dtype: object), ('110024262', 14585    R
#   14677    R
#   Name: tipoCredito, dtype: object), ('110024288', 13184    N
#   Name: tipoCredito, dtype: object), ('110024338', 13185    N
#   Name: tipoCredito, dtype: object), ('110024379', 13186    N
#   Name: tipoCredito, dtype: object), ('110024452', 13571    R
#   Name: tipoCredito, dtype: object), ('110024528', 13506    R
#   13658    R
#   Name: tipoCredito, dtype: object), ('110024577', 13463    R
#   Name: tipoCredito, dtype: object), ('110024619', 13245    N
#   Name: tipoCredito, dtype: object), ('110024650', 13189    N
#   Name: tipoCredito, dtype: object), ('110024684', 13555    R
#   14271    R
#   Name: tipoCredito, dtype: object), ('110024866', 13193    N
#   Name: tipoCredito, dtype: object), ('110024981', 11339    U
#   Name: tipoCredito, dtype: object), ('110025004', 14814    R
#   Name: tipoCredito, dtype: object), ('110025020', 13195    N
#   Name: tipoCredito, dtype: object), ('110025079', 14401    R
#   14652    R
#   Name: tipoCredito, dtype: object), ('110025111', 14423    R
#   Name: tipoCredito, dtype: object), ('110025178', 14157    R
#   14264    R
#   Name: tipoCredito, dtype: object), ('110025293', 14530    N
#   Name: tipoCredito, dtype: object), ('110025475', 13496    R
#   Name: tipoCredito, dtype: object), ('110025509', 13467    R
#   Name: tipoCredito, dtype: object), ('110025772', 14604    R
#   Name: tipoCredito, dtype: object), ('110025822', 14592    R
#   Name: tipoCredito, dtype: object), ('110025996', 13476    R
#   Name: tipoCredito, dtype: object), ('110026002', 13508    R
#   Name: tipoCredito, dtype: object), ('110026028', 13198    N
#   Name: tipoCredito, dtype: object), ('110026184', 13199    N
#   Name: tipoCredito, dtype: object), ('110026200', 13255    R
#   Name: tipoCredito, dtype: object), ('110026291', 30005    R
#   Name: tipoCredito, dtype: object), ('110026309', 13200    N
#   Name: tipoCredito, dtype: object), ('110026333', 14332    N
#   Name: tipoCredito, dtype: object), ('110026630', 13565    R
#   Name: tipoCredito, dtype: object), ('110026705', 13202    N
#   Name: tipoCredito, dtype: object), ('110026721', 14273    U
#   Name: tipoCredito, dtype: object), ('110026770', 14521    R
#   Name: tipoCredito, dtype: object), ('110026788', 13652    N
#   Name: tipoCredito, dtype: object), ('110026820', 14242    R
#   14498    R
#   14612    R
#   Name: tipoCredito, dtype: object), ('110026911', 13532    R
#   Name: tipoCredito, dtype: object), ('110026952', 14687    R
#   Name: tipoCredito, dtype: object), ('110027141', 13216    N
#   Name: tipoCredito, dtype: object), ('110027273', 13612    R
#   Name: tipoCredito, dtype: object), ('110027331', 13527    R
#   Name: tipoCredito, dtype: object), ('110027380', 14327    R
#   Name: tipoCredito, dtype: object), ('110027422', 11349    R
#   14712    R
#   Name: tipoCredito, dtype: object), ('110027612', 13217    N
#   Name: tipoCredito, dtype: object), ('110027653', 11300    R
#   11322    R
#   Name: tipoCredito, dtype: object), ('110027661', 14837    R
#   Name: tipoCredito, dtype: object), ('110027695', 13218    N
#   Name: tipoCredito, dtype: object), ('110027752', 13606    R
#   Name: tipoCredito, dtype: object), ('110027760', 13554    R
#   Name: tipoCredito, dtype: object), ('110027810', 14610    R
#   14674    R
#   Name: tipoCredito, dtype: object), ('110027950', 10354    N
#   10427    R
#   Name: tipoCredito, dtype: object), ('110027976', 13219    N
#   Name: tipoCredito, dtype: object), ('110028008', 13491    R
#   Name: tipoCredito, dtype: object), ('110028040', 14661    R
#   Name: tipoCredito, dtype: object), ('110028107', 13271    R
#   Name: tipoCredito, dtype: object), ('110028180', 13221    N
#   Name: tipoCredito, dtype: object), ('110028206', 14738    R
#   Name: tipoCredito, dtype: object), ('110028370', 13223    N
#   Name: tipoCredito, dtype: object), ('110028446', 14313    R
#   Name: tipoCredito, dtype: object), ('110028453', 14316    R
#   Name: tipoCredito, dtype: object), ('110028537', 13289    R
#   Name: tipoCredito, dtype: object), ('110028644', 13249    N
#   Name: tipoCredito, dtype: object), ('110028677', 11298    R
#   Name: tipoCredito, dtype: object), ('110028891', 14832    R
#   Name: tipoCredito, dtype: object), ('110028917', 13257    R
#   Name: tipoCredito, dtype: object), ('110028925', 13227    N
#   Name: tipoCredito, dtype: object), ('110028941', 13225    N
#   Name: tipoCredito, dtype: object), ('110028958', 13226    N
#   Name: tipoCredito, dtype: object), ('110028982', 14669    R
#   14801    R
#   Name: tipoCredito, dtype: object), ('110029063', 13228    N
#   13543    R
#   Name: tipoCredito, dtype: object), ('110029105', 14720    R
#   Name: tipoCredito, dtype: object), ('110029113', 13648    R
#   Name: tipoCredito, dtype: object), ('110029428', 13229    N
#   Name: tipoCredito, dtype: object), ('110029493', 10721    R
#   Name: tipoCredito, dtype: object), ('110029600', 30019    R
#   Name: tipoCredito, dtype: object), ('110029626', 11314    R
#   11329    R
#   Name: tipoCredito, dtype: object), ('110029667', 14322    R
#   Name: tipoCredito, dtype: object), ('110029683', 13231    N
#   Name: tipoCredito, dtype: object), ('110029717', 11333    R
#   Name: tipoCredito, dtype: object), ('110029857', 13459    N
#   Name: tipoCredito, dtype: object), ('110029865', 13261    R
#   Name: tipoCredito, dtype: object), ('110029907', 13579    R
#   Name: tipoCredito, dtype: object), ('110030012', 14299    R
#   Name: tipoCredito, dtype: object), ('110030202', 13233    N
#   Name: tipoCredito, dtype: object), ('110030319', 13497    R
#   Name: tipoCredito, dtype: object), ('110030418', 14490    R
#   Name: tipoCredito, dtype: object), ('110030491', 13234    N
#   Name: tipoCredito, dtype: object), ('110030517', 14657    R
#   Name: tipoCredito, dtype: object), ('110030582', 14602    R
#   Name: tipoCredito, dtype: object), ('110030707', 14546    R
#   14671    R
#   Name: tipoCredito, dtype: object), ('110030756', 14245    R
#   Name: tipoCredito, dtype: object), ('110030764', 13236    N
#   Name: tipoCredito, dtype: object), ('110030863', 13647    R
#   Name: tipoCredito, dtype: object), ('110031093', 13560    R
#   Name: tipoCredito, dtype: object), ('110031101', 13238    N
#   Name: tipoCredito, dtype: object), ('110031168', 14867    R
#   Name: tipoCredito, dtype: object), ('110031648', 13557    R
#   Name: tipoCredito, dtype: object), ('110031689', 14613    R
#   Name: tipoCredito, dtype: object), ('110031796', 13448    N
#   Name: tipoCredito, dtype: object), ('110031804', 29992    R
#   Name: tipoCredito, dtype: object), ('110031846', 13449    N
#   Name: tipoCredito, dtype: object), ('110031929', 13585    R
#   Name: tipoCredito, dtype: object), ('110032224', 13591    R
#   Name: tipoCredito, dtype: object), ('110032398', 13451    N
#   Name: tipoCredito, dtype: object), ('110032414', 14698    R
#   14770    R
#   Name: tipoCredito, dtype: object), ('110032471', 13450    N
#   Name: tipoCredito, dtype: object), ('110032497', 13452    N
#   Name: tipoCredito, dtype: object), ('110032562', 13595    R
#   14307    R
#   Name: tipoCredito, dtype: object), ('110032745', 14545    R
#   Name: tipoCredito, dtype: object), ('110032760', 14399    R
#   Name: tipoCredito, dtype: object), ('110032950', 13250    N
#   Name: tipoCredito, dtype: object), ('110033065', 14430    R
#   Name: tipoCredito, dtype: object), ('110033206', 14240    R
#   Name: tipoCredito, dtype: object), ('110033255', 30100    U
#   Name: tipoCredito, dtype: object), ('110033313', 13457    N
#   Name: tipoCredito, dtype: object), ('110033339', 13262    R
#   Name: tipoCredito, dtype: object), ('110033461', 11119    R
#   Name: tipoCredito, dtype: object), ('110033586', 14398    R
#   14599    R
#   Name: tipoCredito, dtype: object), ('110033644', 14226    R
#   Name: tipoCredito, dtype: object), ('110033750', 10838    N
#   Name: tipoCredito, dtype: object), ('110033826', 13479    N
#   Name: tipoCredito, dtype: object), ('110033925', 13601    R
#   14340    R
#   Name: tipoCredito, dtype: object), ('110034378', 14219    R
#   Name: tipoCredito, dtype: object), ('110034469', 13464    N
#   Name: tipoCredito, dtype: object), ('110034683', 13588    R
#   Name: tipoCredito, dtype: object), ('110034808', 14358    R
#   Name: tipoCredito, dtype: object), ('110034915', 14715    R
#   14874    R
#   Name: tipoCredito, dtype: object), ('110034972', 14880    R
#   Name: tipoCredito, dtype: object), ('110034980', 13335    R
#   Name: tipoCredito, dtype: object), ('110035086', 14306    R
#   Name: tipoCredito, dtype: object), ('110035177', 13609    R
#   Name: tipoCredito, dtype: object), ('110035359', 14228    R
#   Name: tipoCredito, dtype: object), ('110035391', 14323    N
#   Name: tipoCredito, dtype: object), ('110035540', 13613    R
#   Name: tipoCredito, dtype: object), ('110035672', 13251    N
#   Name: tipoCredito, dtype: object), ('110035722', 13632    R
#   Name: tipoCredito, dtype: object), ('110035755', 13469    N
#   13592    R
#   Name: tipoCredito, dtype: object), ('110035920', 13586    R
#   Name: tipoCredito, dtype: object), ('110035979', 13542    R
#   13625    R
#   Name: tipoCredito, dtype: object), ('110035987', 13470    N
#   13663    R
#   Name: tipoCredito, dtype: object), ('110035995', 14414    R
#   Name: tipoCredito, dtype: object), ('110036027', 13598    R
#   Name: tipoCredito, dtype: object), ('110036068', 14308    R
#   Name: tipoCredito, dtype: object), ('110036092', 13471    N
#   Name: tipoCredito, dtype: object), ('110036118', 11303    R
#   11332    R
#   Name: tipoCredito, dtype: object), ('110036142', 13252    N
#   Name: tipoCredito, dtype: object), ('110036258', 20392    R
#   20766    R
#   Name: tipoCredito, dtype: object), ('110036266', 14251    N
#   Name: tipoCredito, dtype: object), ('110036399', 13473    N
#   Name: tipoCredito, dtype: object), ('110036498', 14176    R
#   Name: tipoCredito, dtype: object), ('110036639', 13475    N
#   13619    R
#   Name: tipoCredito, dtype: object), ('110036852', 14305    R
#   14377    R
#   14446    R
#   Name: tipoCredito, dtype: object), ('110036878', 14559    U
#   Name: tipoCredito, dtype: object), ('110036928', 14473    R
#   Name: tipoCredito, dtype: object), ('110036944', 13477    N
#   Name: tipoCredito, dtype: object), ('110037280', 13480    N
#   Name: tipoCredito, dtype: object), ('110037314', 13481    N
#   13651    R
#   Name: tipoCredito, dtype: object), ('110037397', 13483    N
#   Name: tipoCredito, dtype: object), ('110037439', 13484    N
#   13649    R
#   Name: tipoCredito, dtype: object), ('110037454', 14425    R
#   Name: tipoCredito, dtype: object), ('110037512', 14565    R
#   Name: tipoCredito, dtype: object), ('110037546', 13485    N
#   13589    R
#   Name: tipoCredito, dtype: object), ('110037769', 14651    R
#   Name: tipoCredito, dtype: object), ('110037793', 13486    N
#   Name: tipoCredito, dtype: object), ('110037942', 14537    R
#   Name: tipoCredito, dtype: object), ('110038098', 14230    R
#   14497    R
#   Name: tipoCredito, dtype: object), ('110038304', 13487    N
#   Name: tipoCredito, dtype: object), ('110038411', 13253    N
#   Name: tipoCredito, dtype: object), ('110038502', 14343    R
#   Name: tipoCredito, dtype: object), ('110038767', 14298    R
#   Name: tipoCredito, dtype: object), ('110038882', 14374    R
#   Name: tipoCredito, dtype: object), ('110038932', 14311    U
#   Name: tipoCredito, dtype: object), ('110039054', 14424    R
#   14769    R
#   Name: tipoCredito, dtype: object), ('110039286', 14500    R
#   Name: tipoCredito, dtype: object), ('110039427', 13626    R
#   Name: tipoCredito, dtype: object), ('110039617', 11320    R
#   11336    R
#   Name: tipoCredito, dtype: object), ('110039773', 13492    N
#   Name: tipoCredito, dtype: object), ('110039807', 13254    N
#   Name: tipoCredito, dtype: object), ('110039815', 13495    N
#   Name: tipoCredito, dtype: object), ('110039831', 13494    N
#   Name: tipoCredito, dtype: object), ('110039930', 14440    R
#   Name: tipoCredito, dtype: object), ('110040011', 14437    N
#   Name: tipoCredito, dtype: object), ('110040094', 13502    N
#   Name: tipoCredito, dtype: object), ('110040136', 13383    R
#   Name: tipoCredito, dtype: object), ('110040243', 13501    N
#   Name: tipoCredito, dtype: object), ('110040334', 13500    N
#   Name: tipoCredito, dtype: object), ('110040367', 14696    R
#   Name: tipoCredito, dtype: object), ('110040391', 14522    U
#   Name: tipoCredito, dtype: object), ('110040862', 14462    R
#   14501    R
#   Name: tipoCredito, dtype: object), ('110040953', 13634    R
#   Name: tipoCredito, dtype: object), ('110041167', 13507    N
#   Name: tipoCredito, dtype: object), ('110041795', 13437    U
#   Name: tipoCredito, dtype: object), ('110041886', 14400    R
#   Name: tipoCredito, dtype: object), ('110041910', 13511    N
#   Name: tipoCredito, dtype: object), ('110041951', 13512    N
#   Name: tipoCredito, dtype: object), ('110041993', 13513    N
#   Name: tipoCredito, dtype: object), ('110042025', 13664    R
#   Name: tipoCredito, dtype: object), ('110042082', 13514    N
#   Name: tipoCredito, dtype: object), ('110042090', 13515    N
#   Name: tipoCredito, dtype: object), ('110042108', 13524    N
#   Name: tipoCredito, dtype: object), ('110042173', 30026    U
#   Name: tipoCredito, dtype: object), ('110042207', 10983    N
#   Name: tipoCredito, dtype: object), ('110042264', 13523    N
#   13653    R
#   Name: tipoCredito, dtype: object), ('110042413', 13528    N
#   Name: tipoCredito, dtype: object), ('110042470', 13535    N
#   Name: tipoCredito, dtype: object), ('110042496', 13256    N
#   Name: tipoCredito, dtype: object), ('110042538', 13529    N
#   Name: tipoCredito, dtype: object), ('110042611', 14384    R
#   Name: tipoCredito, dtype: object), ('110042629', 13530    N
#   Name: tipoCredito, dtype: object), ('110042736', 29997    R
#   30048    R
#   Name: tipoCredito, dtype: object), ('110042850', 11110    N
#   Name: tipoCredito, dtype: object), ('110043064', 11328    R
#   Name: tipoCredito, dtype: object), ('110043163', 13534    N
#   Name: tipoCredito, dtype: object), ('110043205', 13642    R
#   Name: tipoCredito, dtype: object), ('110043395', 13537    N
#   Name: tipoCredito, dtype: object), ('110043445', 14227    R
#   14304    R
#   14420    R
#   Name: tipoCredito, dtype: object), ('110043460', 13538    N
#   Name: tipoCredito, dtype: object), ('110043627', 14201    R
#   Name: tipoCredito, dtype: object), ('110043742', 14336    R
#   Name: tipoCredito, dtype: object), ('110044070', 13547    N
#   Name: tipoCredito, dtype: object), ('110044435', 13550    N
#   14310    R
#   Name: tipoCredito, dtype: object), ('110044542', 14150    R
# ...
#   Name: tipoCredito, dtype: object), ('110044997', 13656    R
#   Name: tipoCredito, dtype: object), ('110045127', 14178    R
#   Name: tipoCredito, dtype: object), ('110045283', 13558    N
#   Name: tipoCredito, dtype: object), ('110045291', 13306    R
#   Name: tipoCredito, dtype: object), ('110045333', 13566    N
#   Name: tipoCredito, dtype: object), ('110045374', 13561    N
#   Name: tipoCredito, dtype: object), ('110045481', 14670    R
#   Name: tipoCredito, dtype: object), ('110045507', 13659    R
#   Name: tipoCredito, dtype: object), ('110045523', 13559    N
#   Name: tipoCredito, dtype: object), ('110045655', 14225    R
#   Name: tipoCredito, dtype: object), ('110045671', 13563    N
#   13617    R
#   Name: tipoCredito, dtype: object), ('110045697', 13564    N
#   Name: tipoCredito, dtype: object), ('110045887', 14303    R
#   14315    R
#   Name: tipoCredito, dtype: object), ('110046018', 14844    R
#   Name: tipoCredito, dtype: object), ('110046323', 13567    N
#   Name: tipoCredito, dtype: object), ('110046471', 14428    R
#   Name: tipoCredito, dtype: object), ('110046505', 13568    N
#   Name: tipoCredito, dtype: object), ('110046570', 13569    N
#   Name: tipoCredito, dtype: object), ('110046927', 13258    N
#   Name: tipoCredito, dtype: object), ('110046935', 14614    R
#   Name: tipoCredito, dtype: object), ('110046943', 14347    R
#   14542    R
#   Name: tipoCredito, dtype: object), ('110046950', 13573    N
#   Name: tipoCredito, dtype: object), ('110047016', 13574    N
#   Name: tipoCredito, dtype: object), ('110047032', 13575    N
#   Name: tipoCredito, dtype: object), ('110047065', 14580    R
#   Name: tipoCredito, dtype: object), ('110047099', 14204    R
#   Name: tipoCredito, dtype: object), ('110047149', 13577    N
#   Name: tipoCredito, dtype: object), ('110047156', 13578    N
#   Name: tipoCredito, dtype: object), ('110047495', 13580    N
#   Name: tipoCredito, dtype: object), ('110047552', 13355    R
#   14813    R
#   Name: tipoCredito, dtype: object), ('110047594', 14848    R
#   Name: tipoCredito, dtype: object), ('110047651', 14267    R
#   Name: tipoCredito, dtype: object), ('110047677', 13584    N
#   Name: tipoCredito, dtype: object), ('110047727', 13582    N
#   Name: tipoCredito, dtype: object), ('110047818', 30007    N
#   Name: tipoCredito, dtype: object), ('110047859', 13583    N
#   Name: tipoCredito, dtype: object), ('110047974', 14734    R
#   Name: tipoCredito, dtype: object), ('110048055', 13285    R
#   Name: tipoCredito, dtype: object), ('110048097', 13587    N
#   Name: tipoCredito, dtype: object), ('110048139', 14248    R
#   Name: tipoCredito, dtype: object), ('110048238', 14378    R
#   Name: tipoCredito, dtype: object), ('110048345', 13602    N
#   Name: tipoCredito, dtype: object), ('110048600', 13259    N
#   Name: tipoCredito, dtype: object), ('110048634', 13594    N
#   Name: tipoCredito, dtype: object), ('110048782', 14183    R
#   Name: tipoCredito, dtype: object), ('110048808', 13596    N
#   Name: tipoCredito, dtype: object), ('110048873', 13597    N
#   14244    R
#   Name: tipoCredito, dtype: object), ('110049053', 13260    N
#   Name: tipoCredito, dtype: object), ('110049202', 30108    R
#   Name: tipoCredito, dtype: object), ('110049293', 14324    R
#   Name: tipoCredito, dtype: object), ('110049525', 14318    R
#   Name: tipoCredito, dtype: object), ('110049566', 14596    N
#   Name: tipoCredito, dtype: object), ('110049780', 13280    R
#   Name: tipoCredito, dtype: object), ('110049939', 14682    U
#   14817    R
#   14826    R
#   Name: tipoCredito, dtype: object), ('110050119', 13605    N
#   Name: tipoCredito, dtype: object), ('110050382', 11327    R
#   Name: tipoCredito, dtype: object), ('110050408', 14314    R
#   Name: tipoCredito, dtype: object), ('110050465', 30030    R
#   30066    R
#   Name: tipoCredito, dtype: object), ('110050523', 11347    R
#   Name: tipoCredito, dtype: object), ('110050549', 13607    N
#   Name: tipoCredito, dtype: object), ('110050721', 14438    R
#   Name: tipoCredito, dtype: object), ('110050747', 13611    N
#   Name: tipoCredito, dtype: object), ('110050754', 14265    R
#   Name: tipoCredito, dtype: object), ('110050887', 13263    N
#   Name: tipoCredito, dtype: object), ('110050937', 13615    N
#   Name: tipoCredito, dtype: object), ('110050960', 14342    R
#   14451    R
#   Name: tipoCredito, dtype: object), ('110051000', 13264    N
#   Name: tipoCredito, dtype: object), ('110051026', 14575    R
#   Name: tipoCredito, dtype: object), ('110051273', 14457    N
#   Name: tipoCredito, dtype: object), ('110051406', 13618    N
#   Name: tipoCredito, dtype: object), ('110051562', 14493    R
#   Name: tipoCredito, dtype: object), ('110051653', 14341    R
#   Name: tipoCredito, dtype: object), ('110051976', 14584    R
#   Name: tipoCredito, dtype: object), ('110051992', 13621    N
#   Name: tipoCredito, dtype: object), ('110052164', 13624    N
#   Name: tipoCredito, dtype: object), ('110052339', 13287    R
#   Name: tipoCredito, dtype: object), ('110052347', 30084    U
#   Name: tipoCredito, dtype: object), ('110052479', 13622    N
#   Name: tipoCredito, dtype: object), ('110052560', 14179    R
#   Name: tipoCredito, dtype: object), ('110052602', 13623    N
#   Name: tipoCredito, dtype: object), ('110052750', 14474    R
#   Name: tipoCredito, dtype: object), ('110052768', 13265    N
#   Name: tipoCredito, dtype: object), ('110052917', 14475    R
#   Name: tipoCredito, dtype: object), ('110053014', 14326    R
#   14502    R
#   Name: tipoCredito, dtype: object), ('110053196', 13266    N
#   Name: tipoCredito, dtype: object), ('110053493', 13628    N
#   Name: tipoCredito, dtype: object), ('110053659', 13338    R
#   Name: tipoCredito, dtype: object), ('110053725', 14331    R
#   Name: tipoCredito, dtype: object), ('110053758', 14777    R
#   14865    R
#   Name: tipoCredito, dtype: object), ('110053972', 13631    N
#   Name: tipoCredito, dtype: object), ('110053980', 14583    R
#   29993    R
#   Name: tipoCredito, dtype: object), ('110054053', 19786    R
#   Name: tipoCredito, dtype: object), ('110054137', 14247    N
#   Name: tipoCredito, dtype: object), ('110054244', 13269    N
#   Name: tipoCredito, dtype: object), ('110054517', 13267    N
#   Name: tipoCredito, dtype: object), ('110054558', 13293    R
#   Name: tipoCredito, dtype: object), ('110054590', 29999    R
#   Name: tipoCredito, dtype: object), ('110054715', 14361    R
#   Name: tipoCredito, dtype: object), ('110054731', 13637    N
#   Name: tipoCredito, dtype: object), ('110054756', 13268    N
#   Name: tipoCredito, dtype: object), ('110054814', 14601    R
#   Name: tipoCredito, dtype: object), ('110054822', 14673    R
#   Name: tipoCredito, dtype: object), ('110054848', 13270    N
#   Name: tipoCredito, dtype: object), ('110054988', 13638    N
#   Name: tipoCredito, dtype: object), ('110055035', 13639    N
#   Name: tipoCredito, dtype: object), ('110055126', 13640    N
#   Name: tipoCredito, dtype: object), ('110055217', 14335    R
#   Name: tipoCredito, dtype: object), ('110055233', 14659    R
#   Name: tipoCredito, dtype: object), ('110055324', 14385    R
#   Name: tipoCredito, dtype: object), ('110055340', 13644    N
#   Name: tipoCredito, dtype: object), ('110055373', 13272    N
#   Name: tipoCredito, dtype: object), ('110055381', 13645    N
#   Name: tipoCredito, dtype: object), ('110055449', 13646    N
#   14268    R
#   Name: tipoCredito, dtype: object), ('110055696', 13273    N
#   Name: tipoCredito, dtype: object), ('110055795', 14333    R
#   Name: tipoCredito, dtype: object), ('110055860', 14758    R
#   Name: tipoCredito, dtype: object), ('110055886', 13650    N
#   Name: tipoCredito, dtype: object), ('110055951', 11311    U
#   Name: tipoCredito, dtype: object), ('110056066', 14357    R
#   Name: tipoCredito, dtype: object), ('110056264', 13654    N
#   Name: tipoCredito, dtype: object), ('110056330', 13655    N
#   Name: tipoCredito, dtype: object), ('110056405', 14402    R
#   Name: tipoCredito, dtype: object), ('110056421', 14581    R
#   Name: tipoCredito, dtype: object), ('110056470', 13317    R
#   Name: tipoCredito, dtype: object), ('110056488', 14470    R
#   Name: tipoCredito, dtype: object), ('110056546', 13274    N
#   Name: tipoCredito, dtype: object), ('110056769', 13275    N
#   14359    R
#   Name: tipoCredito, dtype: object), ('110056868', 13657    N
#   Name: tipoCredito, dtype: object), ('110056926', 13661    N
#   14405    R
#   Name: tipoCredito, dtype: object), ('110056942', 13662    N
#   Name: tipoCredito, dtype: object), ('110057205', 14149    N
#   Name: tipoCredito, dtype: object), ('110057528', 14574    U
#   Name: tipoCredito, dtype: object), ('110057668', 14151    N
#   Name: tipoCredito, dtype: object), ('110057791', 13284    R
#   Name: tipoCredito, dtype: object), ('110057858', 14152    N
#   Name: tipoCredito, dtype: object), ('110057874', 14266    R
#   14422    R
#   Name: tipoCredito, dtype: object), ('110057999', 14154    N
#   Name: tipoCredito, dtype: object), ('110058005', 14153    N
#   Name: tipoCredito, dtype: object), ('110058096', 14508    N
#   Name: tipoCredito, dtype: object), ('110058245', 14379    R
#   Name: tipoCredito, dtype: object), ('110058641', 29987    R
#   Name: tipoCredito, dtype: object), ('110058666', 14407    R
#   Name: tipoCredito, dtype: object), ('110058690', 14519    R
#   Name: tipoCredito, dtype: object), ('110058773', 14174    N
#   Name: tipoCredito, dtype: object), ('110058997', 13278    N
#   Name: tipoCredito, dtype: object), ('110059177', 14177    N
#   Name: tipoCredito, dtype: object), ('110059193', 11118    N
#   Name: tipoCredito, dtype: object), ('110059367', 13279    N
#   Name: tipoCredito, dtype: object), ('110059615', 14789    R
#   Name: tipoCredito, dtype: object), ('110059623', 14783    R
#   Name: tipoCredito, dtype: object), ('110059961', 14182    N
#   Name: tipoCredito, dtype: object), ('110059979', 14181    N
#   14338    R
#   Name: tipoCredito, dtype: object), ('110060001', 14196    N
#   Name: tipoCredito, dtype: object), ('110060159', 14434    R
#   Name: tipoCredito, dtype: object), ('110060209', 14453    R
#   14548    R
#   Name: tipoCredito, dtype: object), ('110060233', 14197    N
#   Name: tipoCredito, dtype: object), ('110060407', 11337    R
#   Name: tipoCredito, dtype: object), ('110060597', 14466    R
#   14697    R
#   Name: tipoCredito, dtype: object), ('110060704', 13301    R
#   Name: tipoCredito, dtype: object), ('110060985', 14468    R
#   14675    R
#   Name: tipoCredito, dtype: object), ('110061025', 14586    R
#   Name: tipoCredito, dtype: object), ('110061561', 14370    R
#   Name: tipoCredito, dtype: object), ('110061710', 14836    U
#   Name: tipoCredito, dtype: object), ('110061751', 14205    N
#   Name: tipoCredito, dtype: object), ('110061884', 14218    N
#   Name: tipoCredito, dtype: object), ('110062213', 14221    N
#   Name: tipoCredito, dtype: object), ('110062254', 14365    R
#   Name: tipoCredito, dtype: object), ('110062320', 14222    N
#   Name: tipoCredito, dtype: object), ('110062395', 14382    R
#   14556    R
#   Name: tipoCredito, dtype: object), ('110062403', 14868    N
#   Name: tipoCredito, dtype: object), ('110062577', 14517    R
#   Name: tipoCredito, dtype: object), ('110062734', 14685    R
#   Name: tipoCredito, dtype: object), ('110063401', 14223    N
#   Name: tipoCredito, dtype: object), ('110063443', 14224    N
#   Name: tipoCredito, dtype: object), ('110063690', 11317    R
#   Name: tipoCredito, dtype: object), ('110063716', 13282    N
#   Name: tipoCredito, dtype: object), ('110063807', 13318    R
#   Name: tipoCredito, dtype: object), ('110063963', 11352    U
#   Name: tipoCredito, dtype: object), ('110064326', 14234    N
#   Name: tipoCredito, dtype: object), ('110064649', 14598    R
#   Name: tipoCredito, dtype: object), ('110064664', 14229    N
#   Name: tipoCredito, dtype: object), ('110065091', 13283    N
#   Name: tipoCredito, dtype: object), ('110065182', 10675    N
#   Name: tipoCredito, dtype: object), ('110065273', 13323    R
#   Name: tipoCredito, dtype: object), ('110065612', 13329    N
#   Name: tipoCredito, dtype: object), ('110065687', 14233    N
#   Name: tipoCredito, dtype: object), ('110065703', 14615    R
#   Name: tipoCredito, dtype: object), ('110065869', 14235    N
#   Name: tipoCredito, dtype: object), ('110065992', 14236    N
#   Name: tipoCredito, dtype: object), ('110066263', 13313    R
#   Name: tipoCredito, dtype: object), ('110066289', 14394    R
#   14452    R
#   Name: tipoCredito, dtype: object), ('110066362', 14239    N
#   Name: tipoCredito, dtype: object), ('110066487', 14241    N
#   Name: tipoCredito, dtype: object), ('110066693', 14431    R
#   Name: tipoCredito, dtype: object), ('110066719', 13286    N
#   Name: tipoCredito, dtype: object), ('110066727', 13288    N
#   Name: tipoCredito, dtype: object), ('110066768', 14243    N
#   Name: tipoCredito, dtype: object), ('110066842', 14246    N
#   Name: tipoCredito, dtype: object), ('110066859', 29990    R
#   Name: tipoCredito, dtype: object), ('110066982', 14416    R
#   Name: tipoCredito, dtype: object), ('110066990', 14249    N
#   Name: tipoCredito, dtype: object), ('110067063', 14442    R
#   Name: tipoCredito, dtype: object), ('110067121', 11319    R
#   Name: tipoCredito, dtype: object), ('110067188', 14269    N
#   14495    R
#   Name: tipoCredito, dtype: object), ('110067261', 30056    R
#   Name: tipoCredito, dtype: object), ('110067451', 14250    N
#   14499    R
#   Name: tipoCredito, dtype: object), ('110067683', 14263    N
#   Name: tipoCredito, dtype: object), ('110067782', 14417    R
#   Name: tipoCredito, dtype: object), ('110067881', 14504    R
#   14636    R
#   Name: tipoCredito, dtype: object), ('110068277', 14655    R
#   Name: tipoCredito, dtype: object), ('110068624', 14535    R
#   14701    R
#   Name: tipoCredito, dtype: object), ('110068640', 14454    R
#   Name: tipoCredito, dtype: object), ('110068764', 14634    R
#   Name: tipoCredito, dtype: object), ('110068830', 14647    R
#   Name: tipoCredito, dtype: object), ('110068871', 14503    R
#   Name: tipoCredito, dtype: object), ('110069028', 30127    R
#   Name: tipoCredito, dtype: object), ('110069192', 14317    N
#   Name: tipoCredito, dtype: object), ('110069507', 14321    N
#   Name: tipoCredito, dtype: object), ('110069515', 14810    U
#   Name: tipoCredito, dtype: object), ('110069549', 14727    R
#   Name: tipoCredito, dtype: object), ('110069671', 29996    R
#   30067    R
#   Name: tipoCredito, dtype: object), ('110069887', 14325    N
#   Name: tipoCredito, dtype: object), ('110069929', 30033    R
#   30090    R
#   Name: tipoCredito, dtype: object), ('110069960', 14590    R
#   30023    R
#   30089    R
#   Name: tipoCredito, dtype: object), ('110070091', 14582    R
#   Name: tipoCredito, dtype: object), ('110070216', 14386    R
#   Name: tipoCredito, dtype: object), ('110070240', 14415    R
#   Name: tipoCredito, dtype: object), ('110070380', 13290    N
#   Name: tipoCredito, dtype: object), ('110070455', 14421    N
#   Name: tipoCredito, dtype: object), ('110070463', 13307    R
#   Name: tipoCredito, dtype: object), ('110070497', 14516    R
#   Name: tipoCredito, dtype: object), ('110070547', 14329    N
#   Name: tipoCredito, dtype: object), ('110070570', 14330    N
#   14520    R
#   Name: tipoCredito, dtype: object), ('110070596', 14450    R
#   Name: tipoCredito, dtype: object), ('110070679', 14591    R
#   14700    R
#   Name: tipoCredito, dtype: object), ('110070828', 14334    N
#   Name: tipoCredito, dtype: object), ('110071057', 14467    R
#   Name: tipoCredito, dtype: object), ('110071271', 13291    N
#   Name: tipoCredito, dtype: object), ('110071701', 14793    R
#   Name: tipoCredito, dtype: object), ('110071735', 14579    R
#   Name: tipoCredito, dtype: object), ('110071792', 11304    N
#   Name: tipoCredito, dtype: object), ('110071867', 14593    R
#   Name: tipoCredito, dtype: object), ('110071883', 14538    R
#   Name: tipoCredito, dtype: object), ('110072048', 14337    N
#   Name: tipoCredito, dtype: object), ('110072113', 14543    R
#   Name: tipoCredito, dtype: object), ('110072188', 14346    N
#   Name: tipoCredito, dtype: object), ('110072436', 14356    N
#   Name: tipoCredito, dtype: object), ('110072535', 14794    R
#   Name: tipoCredito, dtype: object), ('110072618', 14344    N
#   Name: tipoCredito, dtype: object), ('110072691', 14353    N
#   Name: tipoCredito, dtype: object), ...]

# %% [markdown]
# ### Datos Cuantitativos

# %%
df.describe(include=['float'])
# Out:
#        montoApertura  capitalDesembolsado  capitalCalculado  capitalPagado  \
# count   30575.000000         30575.000000      30575.000000   30575.000000
# mean     4088.209333          4088.209333        492.506614    1980.086606
# std      5730.990950          5730.990950       1702.296340    3508.842342
# min       138.490000           138.490000          0.000000       0.000000
# 25%      1000.000000          1000.000000          0.000000     363.740000
# 50%      2000.000000          2000.000000          0.000000     857.680000
# 75%      5000.000000          5000.000000        301.390000    1981.075000
# max     60000.000000         60000.000000      45472.100000   59840.580000
#
#             ntasint       nintpen        nintcal       nintpag       nintmor  \
# count  30575.000000  30575.000000   30575.000000  30575.000000  30575.000000
# mean       3.672766      4.063522    2151.360212    920.631643    124.388991
# std        0.669596    327.803566    7875.313695   1797.859473    508.811220
# min        1.093000      0.000000      36.510000      0.000000      0.000000
# 25%        3.290000      0.000000     392.700000    154.305000     25.670000
# 50%        3.490000      0.000000     761.680000    378.920000     43.690000
# 75%        3.990000      0.000000    1618.115000    863.015000     79.610000
# max        7.000000  55810.240000  467399.970000  86505.470000  26449.320000
#
#             npagcta       nmorpag       ngastos       ngaspag       nTasEfe
# count  30575.000000  30575.000000  30575.000000  30575.000000  30575.000000
# mean       1.006374     11.384686    113.357102     60.644944      3.670516
# std       41.537166     68.235767    148.052829     91.512420      0.670797
# min        0.000000      0.000000      0.000000      0.000000      1.090000
# 25%        0.000000      0.940000     20.000000      5.000000      3.290000
# 50%        0.000000      3.780000     65.000000     30.300000      3.490000
# 75%        0.000000     10.650000    162.500000     80.000000      3.990000
# max     5416.380000   8792.130000   3354.090000   2486.850000      6.993000

# %%
df.describe(include=['int64'])
# Out:
#              Moneda       ccodprd  modalidadCredito  destinoCredito  \
# count  30575.000000  30575.000000      30575.000000    30575.000000
# mean       1.001145     23.224857          1.022306        3.218021
# std        0.033815      4.149205          0.248288        2.132636
# min        1.000000     21.000000          1.000000        1.000000
# 25%        1.000000     21.000000          1.000000        2.000000
# 50%        1.000000     21.000000          1.000000        2.000000
# 75%        1.000000     21.000000          1.000000        4.000000
# max        2.000000     32.000000          5.000000        8.000000
#
#             ctipper  numeroDeCuotas       ccodana        cCodPdc  \
# count  30575.000000    30575.000000  30575.000000   30575.000000
# mean       1.996500       13.238496   1418.094162   63848.259951
# std        0.059055        5.652038    980.234468   57885.641736
# min        1.000000        1.000000    629.000000   10037.000000
# 25%        2.000000       12.000000    635.000000   10038.000000
# 50%        2.000000       12.000000   1092.000000   40037.000000
# 75%        2.000000       12.000000   1711.000000  120012.000000
# max        2.000000       60.000000   7965.000000  240002.000000
#
#             cCodOfi       nPerGra       nPerLbr
# count  30575.000000  30575.000000  30575.000000
# mean      15.277187      0.000131      1.307800
# std        9.511352      0.014008     10.143641
# min        1.000000      0.000000      0.000000
# 25%        8.000000      0.000000      0.000000
# 50%       14.000000      0.000000      0.000000
# 75%       24.000000      0.000000      0.000000
# max       59.000000      2.000000    210.000000

# %% [markdown]
# ### Datos de Tiempo

# %%
df.describe(include=['datetime'])
# Out:
#               fechaApertura      fechaUltimoPago              dSalPag  \
# count                 30575                29214                 6607
# unique                  907                 2037                  806
# top     2012-08-31 00:00:00  2013-05-28 00:00:00  2012-10-03 00:00:00
# freq                    899                 1049                   85
# first   2009-12-22 00:00:00  2010-02-10 00:00:00  1900-01-01 00:00:00
# last    2012-12-31 00:00:00  2018-08-31 00:00:00  2016-02-05 00:00:00
#
#            fechaVencimiento
# count                 30566
# unique                 1331
# top     2013-12-02 00:00:00
# freq                    326
# first   2010-04-17 00:00:00
# last    2018-01-08 00:00:00

# %% [markdown]
# __Buscando Campos en blanco__

# %%
df.isnull().sum()
# Out:
# codigoCuenta                    0
# codigoCliente                   0
# codigoFuente                    0
# tipoCredito                     0
# Moneda                          0
# ccodprd                         0
# modalidadCredito                0
# sectorEconomico                 0
# destinoCredito                  0
# Fuente de financiamiento        0
# fechaApertura                   0
# ctipper                         0
# ctipcal                         0
# fechaUltimoPago              1361
# montoApertura                   0
# capitalDesembolsado             0
# capitalCalculado                0
# capitalPagado                   0
# ntasint                         0
# nintpen                         0
# nintcal                         0
# nintpag                         0
# nintmor                         0
# npagcta                         0
# nmorpag                         0
# ngastos                         0
# ngaspag                         0
# numeroDeCuotas                  0
# cctapre                         0
# condicionCredito                0
# cmarjud                         0
# ccodana                         0
# dSalPag                     23968
# cCodPdc                         0
# fechaVencimiento                9
# nTasEfe                         0
# cCodOfi                         0
# nPerGra                         0
# nPerLbr                         0
# dtype: int64

# %% [markdown]
# __Filtraremos la data con NaN o NULL__

# %%
diasxmes = 30
# cambiaremos las fechas por sus diferencias en días
df.dropna(subset=['fechaVencimiento'], inplace=True) # quitamos data sin fecha de vencimiento
df['tiempoLimite'] = (df.fechaVencimiento - df.fechaApertura).dt.days/diasxmes
df['tiempoPagando'] = (df.fechaUltimoPago - df.fechaApertura).dt.days/diasxmes
df.drop(['fechaApertura'], axis=1, inplace=True)
df.drop(['fechaUltimoPago'], axis=1, inplace=True)
df.drop(['fechaVencimiento'], axis=1, inplace=True)
df['tiempoPagando'].fillna(0, inplace=True) # quienes no hicieron ningún pago
# Definimos quienes son deudores aún 
df['esDeudor'] = np.int32(df.dSalPag.isnull())#1:deudor, 0:no deudor
df.drop(['dSalPag'], axis=1, inplace=True)
df.isnull().sum()
# Out:
# codigoCuenta                0
# codigoCliente               0
# codigoFuente                0
# tipoCredito                 0
# Moneda                      0
# ccodprd                     0
# modalidadCredito            0
# sectorEconomico             0
# destinoCredito              0
# Fuente de financiamiento    0
# ctipper                     0
# ctipcal                     0
# montoApertura               0
# capitalDesembolsado         0
# capitalCalculado            0
# capitalPagado               0
# ntasint                     0
# nintpen                     0
# nintcal                     0
# nintpag                     0
# nintmor                     0
# npagcta                     0
# nmorpag                     0
# ngastos                     0
# ngaspag                     0
# numeroDeCuotas              0
# cctapre                     0
# condicionCredito            0
# cmarjud                     0
# ccodana                     0
# cCodPdc                     0
# nTasEfe                     0
# cCodOfi                     0
# nPerGra                     0
# nPerLbr                     0
# tiempoLimite                0
# tiempoPagando               0
# esDeudor                    0
# dtype: int64

# %%
#https://chrisalbon.com/python/data_wrangling/pandas_apply_operations_to_groups/
#https://stackoverflow.com/questions/26266362/how-to-count-the-nan-values-in-a-column-in-pandas-dataframe
#https://pandas.pydata.org/pandas-docs/stable/merging.html
#https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html
#https://articulo.mercadolibre.com.pe/MPE-430677380-oferta-ultimo-stock-iphone-7-plus-128gb-4g-nuevo-libre-_JM
